# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 4395  http://news.bbc.co.uk/1/hi/england/2515127.stm...         0
# 4396  > >-- be careful when using this one.) Also, t...         0
# 4397  >>>>> "SM" == Skip Montanaro <skip@pobox.com> ...         0
# 4398  So then, "Mark Hammond" <mhammond@skippinet.co...         0
# 4399  Hi there,\n\n\n\nNow this is probably of no us...         0
#
#                                    FILE_NAME
# 4395  01396.61983fbe6ec43f55fd44e30fce24ffa6
# 4396  01397.9f9ef4c2a8dc012d80f2ce2d3473d3b7
# 4397  01398.169b51731fe569f42169ae8f948ec676
# 4398  01399.ca6b00b7b341bbde9a9ea3dd6a7bf896
# 4399  01400.f897f0931e461e7b2e964d28e927c35e

# %%
data.shape
# Out:
# (4400, 3)

# %%
data.sort_index(inplace=True) # sorting index

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 4395  http://news.bbc.co.uk/1/hi/england/2515127.stm...         0
# 4396  > >-- be careful when using this one.) Also, t...         0
# 4397  >>>>> "SM" == Skip Montanaro <skip@pobox.com> ...         0
# 4398  So then, "Mark Hammond" <mhammond@skippinet.co...         0
# 4399  Hi there,\n\n\n\nNow this is probably of no us...         0
#
#                                    FILE_NAME
# 4395  01396.61983fbe6ec43f55fd44e30fce24ffa6
# 4396  01397.9f9ef4c2a8dc012d80f2ce2d3473d3b7
# 4397  01398.169b51731fe569f42169ae8f948ec676
# 4398  01399.ca6b00b7b341bbde9a9ea3dd6a7bf896
# 4399  01400.f897f0931e461e7b2e964d28e927c35e

# %%
vectorizer = CountVectorizer(stop_words='english') # cremoves stop words

# %%
all_features = vectorizer.fit_transform(data.MESSAGE) # creating a sparse matrix

# %%
all_features.shape # all emails
# Out:
# (4400, 73683)

# %%
vectorizer.vocabulary_ # vocabulary
# Out:
# {'doctype': 23803,
#  'html': 33826,
#  'public': 52287,
#  'w3c': 67619,
#  'dtd': 24618,
#  'transitional': 63740,
#  'en': 26040,
#  'head': 32672,
#  'meta': 43295,
#  'content': 20308,
#  '3d': 4383,
#  'text': 62584,
#  'charset': 18468,
#  '3dwindows': 4602,
#  '1252': 1477,
#  'http': 33841,
#  'equiv': 26497,
#  '3dcontent': 4505,
#  'ype': 71436,
#  'mshtml': 44643,
#  '00': 0,
#  '2314': 3055,
#  '1000': 1093,
#  '3dgenerator': 4524,
#  'body': 16012,
#  'inserted': 36108,
#  'calypso': 17564,
#  'table': 61903,
#  'border': 16174,
#  '3d0': 4384,
#  'cellpadding': 18184,
#  'cellspacing': 18189,
#  '3d2': 4403,
#  'id': 34610,
#  '3d_calyprintheader_': 4470,
#  'ules': 64965,
#  '3dnone': 4556,
#  'style': 60774,
#  'color': 19585,
#  'black': 15649,
#  'display': 23432,
#  'width': 68857,
#  '100': 1092,
#  'tbody': 62174,
#  'tr': 63628,
#  'td': 62235,
#  'colspan': 19604,
#  '3d3': 4417,
#  'hr': 33742,
#  '3dblack': 4487,
#  'noshade': 46453,
#  'size': 58834,
#  '3d1': 4386,
#  'end': 26098,
#  'font': 28921,
#  '000000': 3,
#  'face': 27604,
#  '3dverdana': 4598,
#  'arial': 13073,
#  'helvetica': 32841,
#  'br': 16347,
#  'ff0000': 28151,
#  'copperplate': 20487,
#  'gothic': 31277,
#  'bold': 16053,
#  '3d5': 4443,
#  'ptsize': 52261,
#  '10': 1091,
#  'center': 18208,
#  'save': 57197,
#  '70': 7090,
#  'life': 40829,
#  'insurance': 36215,
#  'ff': 28147,
#  '0000': 2,
#  'spend': 59849,
#  'pt': 52217,
#  'quote': 53454,
#  'savings': 57207,
#  'align': 11996,
#  '3dleft': 4540,
#  'bordercolor': 16177,
#  '111111': 1322,
#  'wi': 68830,
#  'dth': 24624,
#  '3d650': 4456,
#  '35': 4124,
#  '3d4': 4432,
#  'ensurin': 26264,
#  'family': 27735,
#  'financial': 28400,
#  'security': 57749,
#  'important': 35525,
#  'ma': 42102,
#  'kes': 38904,
#  'buying': 16999,
#  'simple': 58703,
#  'affordable': 11336,
#  'provide': 52072,
#  'free': 29334,
#  'access': 10674,
#  'best': 15164,
#  'companies': 19753,
#  'lowest': 41544,
#  'rates': 54014,
#  '3dmiddle': 4545,
#  'valign': 66382,
#  '3dtop': 4592,
#  '18': 1997,
#  'padding': 48834,
#  'left': 40454,
#  '5px': 6282,
#  'right': 55738,
#  'fast': 27811,
#  'eas': 25207,
#  'saves': 57203,
#  'money': 44211,
#  'let': 40562,
#  'help': 32827,
#  'started': 60279,
#  'val': 66362,
#  'ues': 64739,
#  'country': 20667,
#  'new': 45814,
#  'coverage': 20709,
#  'hundreds': 33929,
#  'tho': 62839,
#  'usands': 65834,
#  'dollars': 23872,
#  'requesting': 55151,
#  'lifequote': 40843,
#  'service': 58021,
#  'minutes': 43736,
#  'complete': 19828,
#  'shop': 58414,
#  'compare': 19766,
#  'types': 64364,
#  'height': 32788,
#  '3d50': 4444,
#  '3dcenter': 4502,
#  'href': 33757,
#  'website': 68506,
#  'e365': 25030,
#  'cc': 18021,
#  'savequote': 57200,
#  'click': 19132,
#  'strong': 60697,
#  'protecting': 52029,
#  'investment': 36524,
#  'll': 41184,
#  'eve': 26861,
#  'make': 42344,
#  'sans': 57109,
#  'serif': 57980,
#  'receipt': 54361,
#  'email': 25889,
#  'error': 26584,
#  'wish': 69035,
#  'removed': 54957,
#  'list': 41026,
#  'mailto': 42292,
#  'coins': 19500,
#  'btamail': 16722,
#  'net': 45724,
#  'cn': 19329,
#  'type': 64359,
#  'remove': 54954,
#  'reside': 55225,
#  'state': 60312,
#  'prohibits': 51887,
#  'mail': 42243,
#  'solicitations': 59477,
#  'insuran': 36214,
#  'ce': 18134,
#  'disregard': 23456,
#  'fight': 28323,
#  'risk': 55800,
#  'cancer': 17622,
#  'www': 69684,
#  'adclick': 10961,
#  'ws': 69527,
#  'cfm': 18294,
#  '315': 3985,
#  'pk007': 50549,
#  'slim': 59064,
#  'guaranteed': 31768,
#  'lose': 41484,
#  '12': 1433,
#  'lbs': 40292,
#  '30': 3886,
#  'days': 21922,
#  '249': 3170,
#  'child': 18614,
#  'support': 61166,
#  'deserve': 22658,
#  'legal': 40464,
#  'advice': 11168,
#  '245': 3162,
#  'pk002': 50548,
#  'join': 37994,
#  'web': 68446,
#  'fastest': 27815,
#  'growing': 31648,
#  'singles': 58757,
#  'community': 19741,
#  '259': 3232,
#  'start': 60277,
#  'private': 51712,
#  'photo': 50228,
#  'album': 11942,
#  'online': 47733,
#  '283': 3392,
#  'wonderful': 69255,
#  'day': 21912,
#  'offer': 47405,
#  'manager': 42420,
#  'prizemama': 51731,
#  'leave': 40422,
#  'use': 65849,
#  'link': 40967,
#  'qves': 53477,
#  'com': 19618,
#  'trim': 63906,
#  'ilug': 35357,
#  'linux': 40987,
#  '7c17': 7430,
#  '7c114258': 7428,
#  'irish': 36750,
#  'users': 65892,
#  'group': 31636,
#  'mailman': 42279,
#  'listinfo': 41065,
#  'subscription': 60875,
#  'information': 35914,
#  'maintainer': 42326,
#  'listmaster': 41069,
#  'zzzz': 72823,
#  'spamassassin': 59692,
#  'taint': 61972,
#  'org': 48026,
#  '7c308417': 7434,
#  'adult': 11125,
#  'club': 19235,
#  'offers': 47412,
#  'membership': 43164,
#  'instant': 36173,
#  'sites': 58807,
#  'user': 65869,
#  'password': 49186,
#  '760382': 7271,
#  'internet': 36351,
#  'news': 45843,
#  '08': 536,
#  '02': 258,
#  'just': 38285,
#  'million': 43632,
#  'members': 43163,
#  'signed': 58630,
#  'month': 44258,
#  '721': 7163,
#  '184': 2029,
#  'faq': 27764,
#  'offering': 47410,
#  'advertisers': 11161,
#  'pay': 49290,
#  'ad': 10913,
#  'space': 59657,
#  'don': 23916,
#  'true': 63992,
#  'absolutely': 10558,
#  'cent': 18205,
#  'account': 10720,
#  'friends': 29436,
#  'yes': 71092,
#  'long': 41413,
#  'age': 11429,
#  'sign': 58619,
#  'following': 28901,
#  'links': 40976,
#  'member': 43162,
#  'multi': 44788,
#  'dollar': 23871,
#  'operations': 47859,
#  'policies': 50951,
#  'rules': 56493,
#  'required': 55154,
#  'info': 35894,
#  'won': 69252,
#  'charge': 18448,
#  'pass': 49157,
#  'believe': 15037,
#  'read': 54213,
#  'terms': 62506,
#  'conditions': 19979,
#  'adults': 11129,
#  'farm': 27782,
#  '80': 7709,
#  '71': 7128,
#  '66': 6630,
#  'aid': 11636,
#  'girls': 30812,
#  'animals': 12467,
#  'getting': 30605,
#  'freaky': 29325,
#  'lifetime': 40849,
#  'sexy': 58101,
#  'celebes': 18161,
#  'celebst': 18169,
#  'thousands': 62864,
#  'xxx': 70676,
#  'doing': 23858,
#  'play': 50666,
#  'house': 33657,
#  'porn': 51089,
#  'mega': 43116,
#  'live': 41106,
#  'feeds': 28039,
#  '60': 6440,
#  'cams': 17605,
#  'asian': 13283,
#  'sex': 58088,
#  'fantasies': 27753,
#  'japanese': 37426,
#  'schoolgirls': 57406,
#  'shows': 58481,
#  'lesbian': 40548,
#  'lace': 40017,
#  'jennifer': 37624,
#  'simpson': 58715,
#  'miami': 43484,
#  'fl': 28577,
#  'entertained': 26281,
#  'boyffriend': 16286,
#  'years': 71057,
#  'joe': 37959,
#  'morgan': 44316,
#  'manhattan': 42454,
#  'ny': 46861,
#  'unbelievable': 65095,
#  'removal': 54952,
#  'instructions': 36196,
#  'received': 54365,
#  'advertisement': 11158,
#  'opted': 47907,
#  'receive': 54364,
#  'specials': 59793,
#  'affiliated': 11322,
#  'websites': 68508,
#  'emails': 25901,
#  'opt': 47904,
#  'database': 21848,
#  'optout': 47945,
#  'allow': 12061,
#  '24': 3142,
#  'hours': 33656,
#  'vonolmosatkirekpups': 67227,
#  'thought': 62860,
#  'like': 40881,
#  'freeyankee': 29377,
#  'cgi': 18325,
#  'fy2': 29859,
#  '822slim1': 7834,
#  '822nic1': 7832,
#  '822ppl1': 7833,
#  'daily': 21728,
#  'deals': 22099,
#  'social': 59396,
#  '7c29': 7431,
#  '7c134077': 7429,
#  'events': 26870,
#  'powerhouse': 51266,
#  'gifting': 30760,
#  'program': 51857,
#  'want': 67871,
#  'miss': 43813,
#  'founders': 29147,
#  'major': 42337,
#  'players': 50672,
#  'invitation': 36533,
#  'experts': 27226,
#  'calling': 17546,
#  'way': 68014,
#  'huge': 33873,
#  'cash': 17844,
#  'flow': 28734,
#  'conceived': 19925,
#  'leverage': 40593,
#  '000': 1,
#  '50': 5667,
#  'question': 53389,
#  'wealthy': 68434,
#  'tossing': 63480,
#  'lifeline': 40840,
#  'sake': 56995,
#  'hope': 33556,
#  'grab': 31393,
#  'hold': 33425,
#  'tight': 62994,
#  'ride': 55714,
#  'testimonials': 62561,
#  'hear': 32722,
#  'average': 13836,
#  'people': 49685,
#  've': 66545,
#  'al': 11894,
#  'single': 58754,
#  'mother': 44372,
#  'sure': 61193,
#  'sent': 57912,
#  'pledge': 50702,
#  'got': 31270,
#  'ky': 39772,
#  'didn': 23053,
#  'partner': 49142,
#  'work': 69308,
#  'think': 62812,
#  'decision': 22188,
#  'pick': 50320,
#  'gave': 30269,
#  'leads': 40392,
#  'training': 63691,
#  'ca': 17413,
#  'announcing': 12516,
#  'close': 19205,
#  'sales': 57009,
#  'fax': 27873,
#  'blast': 15692,
#  'immediately': 35437,
#  'entry': 26327,
#  'wait': 67785,
#  '800': 7710,
#  '421': 5012,
#  '6318': 6539,
#  '896': 8387,
#  '6568': 6619,
#  'name__________________________________phone___________________________________________': 45331,
#  'fax_____________________________________email____________________________________________': 27875,
#  'time': 63025,
#  'call_________________________time': 17534,
#  'zone________________________________________': 72420,
#  'message': 43275,
#  'compliance': 19840,
#  'section': 57724,
#  '301': 3898,
#  'paragraph': 49014,
#  '1618': 1823,
#  'transmissions': 63762,
#  'sender': 57878,
#  'stopped': 60537,
#  'cost': 20597,
#  'sending': 57885,
#  'reply': 55071,
#  'address': 10993,
#  'word': 69293,
#  'subject': 60826,
#  'line': 40937,
#  'errors': 26585,
#  'omissions': 47673,
#  'exceptions': 27022,
#  'excluded': 27046,
#  'spam': 59679,
#  'compiled': 19810,
#  'replicate': 55067,
#  'relative': 54817,
#  'seattle': 57689,
#  'marketing': 42590,
#  'gigt': 30773,
#  'turbo': 64170,
#  'team': 62268,
#  'sole': 59473,
#  'purpose': 52403,
#  'communications': 19733,
#  'continued': 20332,
#  'inclusion': 35657,
#  'gracious': 31402,
#  'permission': 49783,
#  'send': 57875,
#  'tesrewinter': 62541,
#  'yahoo': 70914,
#  'deleted': 22409,
#  'wanted': 67872,
#  '14': 1621,
#  'year': 71052,
#  'old': 47600,
#  'fortune': 29111,
#  '500': 5668,
#  'company': 19756,
#  'tremendous': 63856,
#  'rate': 54011,
#  'looking': 41430,
#  'individuals': 35793,
#  'home': 33460,
#  'opportunity': 47883,
#  'excellent': 27014,
#  'income': 35660,
#  'experience': 27210,
#  'train': 63687,
#  'employed': 26000,
#  'career': 17752,
#  'vast': 66456,
#  'opportunities': 47882,
#  'basetel': 14672,
#  'wealthnow': 68433,
#  'energetic': 26148,
#  'self': 57831,
#  'motivated': 44384,
#  'form': 29056,
#  'employement': 26004,
#  'specialist': 59787,
#  'contact': 20271,
#  '4139volw7': 4982,
#  '758dody1425frhm1': 7257,
#  '764smfc8513fcsll40': 7279,
#  'title': 63101,
#  'reliaquote': 54861,
#  'iso': 36868,
#  '8859': 8361,
#  'leftmargin': 40458,
#  'topmargin': 63434,
#  'ffcc99': 28176,
#  'vlink': 67099,
#  'alink': 12004,
#  'ffcc00': 28173,
#  '468': 5164,
#  'bgcolor': 15264,
#  '993366': 9067,
#  '43': 5043,
#  '56': 5939,
#  'theadmanager': 62710,
#  'server': 58013,
#  'asp': 13312,
#  'ad_key': 10930,
#  'yuesbhwakmlk': 71542,
#  'ext': 27303,
#  'target': 62089,
#  '_blank': 9616,
#  'img': 35414,
#  'src': 60080,
#  'banner': 14578,
#  'bannerads': 14580,
#  'images': 35379,
#  'logo6': 41384,
#  'gif': 30752,
#  '120': 1434,
#  '32': 4005,
#  '44': 5076,
#  'nbsp': 45488,
#  '377': 4229,
#  'ffccff': 28177,
#  'headline6': 32694,
#  '220': 2911,
#  '72': 7158,
#  '336699': 4070,
#  '34': 4089,
#  '45': 5112,
#  'tahoma': 61958,
#  'verdana': 66635,
#  'change': 18398,
#  'protect': 52027,
#  'future': 29765,
#  'sufficient': 60993,
#  'middle': 43555,
#  '27': 3318,
#  'freequotes6': 29361,
#  '177': 1964,
#  '3366cc': 4071,
#  '294': 3449,
#  'freequoteform': 29360,
#  'action': 10855,
#  'termlife': 62503,
#  'bin': 15456,
#  'banner_quote_resp': 14579,
#  'method': 43325,
#  'input': 36074,
#  'hidden': 33058,
#  'value': 66391,
#  '51100004022000000321': 5741,
#  'sourceid': 59615,
#  'class': 19035,
#  'hptbcolor': 33715,
#  'ffffff': 28192,
#  'residence': 55226,
#  '65': 6596,
#  'select': 57813,
#  'formscombobox12': 29078,
#  'option': 47933,
#  'selected': 57819,
#  'alabama': 11908,
#  'alaska': 11920,
#  'arizona': 13087,
#  'arkansas': 13092,
#  'california': 17531,
#  'colorado': 19586,
#  'connecticut': 20124,
#  'delaware': 22397,
#  'dc': 21983,
#  'dist': 23483,
#  'columbia': 19607,
#  'florida': 28725,
#  'georgia': 30547,
#  'hawaii': 32537,
#  'idaho': 34739,
#  'illinois': 35333,
#  'indiana': 35757,
#  'iowa': 36607,
#  'kansas': 38670,
#  'kentucky': 38874,
#  'louisiana': 41514,
#  'maine': 42313,
#  'maryland': 42654,
#  'massachusetts': 42674,
#  'michigan': 43503,
#  'minnesota': 43724,
#  'mississippi': 43827,
#  'missouri': 43831,
#  'montana': 44252,
#  'nebraska': 45586,
#  'nevada': 45809,
#  'hampshire': 32305,
#  'jersey': 37641,
#  'mexico': 43348,
#  'york': 71387,
#  'north': 46427,
#  'carolina': 17792,
#  'dakota': 21738,
#  'ohio': 47500,
#  'oklahoma': 47582,
#  'oregon': 48018,
#  'pennsylvania': 49667,
#  'rhode': 55647,
#  'island': 36854,
#  'south': 59623,
#  'tennessee': 62457,
#  'texas': 62581,
#  'utah': 65950,
#  'vermont': 66661,
#  'virginia': 66956,
#  'washington': 67959,
#  'west': 68615,
#  'wisconsin': 69030,
#  'wyoming': 69748,
#  'date': 21864,
#  'birth': 15517,
#  'mm': 43981,
#  'dd': 22040,
#  'yy': 71688,
#  'nowrap': 46524,
#  '01': 192,
#  '03': 333,
#  '04': 383,
#  '05': 420,
#  '06': 452,
#  '07': 485,
#  '09': 594,
#  '11': 1310,
#  '13': 1534,
#  '15': 1711,
#  '16': 1809,
#  '17': 1907,
#  '19': 2082,
#  '20': 2595,
#  '21': 2836,
#  '22': 2910,
#  '23': 3042,
#  '25': 3196,
#  '26': 3253,
#  '28': 3383,
#  '29': 3435,
#  '31': 3961,
#  '33': 4047,
#  '36': 4162,
#  '37': 4206,
#  '38': 4240,
#  '39': 4271,
#  '40': 4898,
#  '41': 4967,
#  '42': 5009,
#  '46': 5148,
#  '47': 5178,
#  '48': 5212,
#  '49': 5250,
#  '51': 5737,
#  '52': 5774,
#  '53': 5806,
#  '54': 5861,
#  '55': 5897,
#  '57': 5971,
#  '58': 5988,
#  '59': 6014,
#  '61': 6480,
#  '62': 6509,
#  '63': 6534,
#  '64': 6561,
#  '67': 6682,
#  '68': 6703,
#  '69': 6726,
#  '73': 7181,
#  '74': 7207,
#  '75': 7235,
#  '76': 7269,
#  '77': 7295,
#  '78': 7322,
#  '79': 7355,
#  '81': 7783,
#  '82': 7818,
#  '83': 7884,
#  '84': 7955,
#  'formsradiobutton1': 29079,
#  'radio': 53807,
#  'male': 42370,
#  'formsradiobutton2': 29080,
#  'female': 28080,
#  'used': 65855,
#  'tobacco': 63297,
#  'products': 51813,
#  'months': 44261,
#  'formsradiobutton4': 29082,
#  'formsradiobutton3': 29081,
#  'formscombobox11': 29077,
#  '100000': 1095,
#  '125000': 1475,
#  '125': 1473,
#  '150000': 1715,
#  '150': 1712,
#  '175000': 1950,
#  '175': 1949,
#  '200000': 2599,
#  '200': 2596,
#  '225000': 2964,
#  '225': 2961,
#  '250000': 3199,
#  '250': 3197,
#  '275000': 3354,
#  '275': 3352,
#  '300000': 3889,
#  '300': 3887,
#  '325000': 4023,
#  '325': 4022,
#  '350000': 4127,
#  '350': 4125,
#  '375000': 4226,
#  '375': 4225,
#  '400000': 4901,
#  '400': 4899,
#  '425000': 5025,
#  '425': 5024,
#  '450000': 5114,
#  '450': 5113,
#  '475000': 5193,
#  '475': 5192,
#  '500000': 5671,
#  '550000': 5900,
#  '550': 5898,
#  '600000': 6443,
#  '600': 6441,
#  '650000': 6599,
#  '650': 6597,
#  '700000': 7092,
#  '700': 7091,
#  '750000': 7238,
#  '750': 7236,
#  '800000': 7712,
#  '850000': 8045,
#  '850': 8044,
#  '900000': 8820,
#  '900': 8818,
#  '950000': 8953,
#  '950': 8951,
#  '1000000': 1096,
#  '1250000': 1476,
#  '1500000': 1716,
#  '1750000': 1951,
#  '2000000': 2600,
#  '2250000': 2965,
#  '2500000': 3200,
#  '3000000': 3890,
#  '3500000': 4128,
#  '4000000': 4902,
#  '4500000': 5115,
#  '5000000': 5672,
#  '6000000': 6444,
#  '7000000': 7093,
#  '8000000': 7713,
#  '9000000': 8821,
#  '10000000': 1097,
#  '11000000': 1313,
#  '12000000': 1437,
#  '13000000': 1537,
#  '14000000': 1624,
#  '15000000': 1717,
#  'need': 45607,
#  'formscombobox10': 29076,
#  'plan': 50623,
#  'formsbutton1': 29075,
#  'submit': 60847,
#  'submitbutton': 60848,
#  'photo6': 50229,
#  'jpg': 38085,
#  '210': 2837,
#  '173': 1934,
#  '217': 2884,
#  'div': 23544,
#  'makes': 42355,
#  'easy': 25224,
#  'instantly': 36176,
#  'quotes': 53457,
#  'highly': 33084,
#  'rated': 54012,
#  '106': 1265,
#  '70percent6': 7125,
#  '131': 1542,
#  'ffcc33': 28174,
#  'today': 63307,
#  '0000ff': 25,
#  'copyright': 20498,
#  '2001': 2606,
#  'rights': 55746,
#  'reserved': 55215,
#  'admanmail': 11053,
#  'hspace': 33794,
#  'vspace': 67378,
#  'alt': 12125,
#  'receiving': 54373,
#  'mailing': 42271,
#  'sendgreatoffers': 57883,
#  'subscribed': 60870,
#  'jm': 37861,
#  'netnoteinc': 45764,
#  'unsubscribe': 65563,
#  'em': 25866,
#  'sgo': 58164,
#  'include': 35652,
#  'unsubscribed': 65566,
#  'correspondence': 20567,
#  'services': 58023,
#  'directed': 23212,
#  'tired': 63086,
#  'bull': 16848,
#  'stop': 60530,
#  'losing': 41489,
#  'real': 54245,
#  'maker': 42353,
#  'big': 15392,
#  'boys': 16291,
#  'drive': 24495,
#  'doorstep': 23962,
#  'short': 58425,
#  'period': 49739,
#  'print': 51676,
#  'successleads': 60947,
#  'firemail': 28462,
#  'telephone': 62392,
#  'number': 46721,
#  'responding': 55294,
#  '499': 5272,
#  '99': 9058,
#  'name___________________________________': 45326,
#  'phone___________________________________': 50214,
#  'fax_____________________________________': 27874,
#  'email___________________________________': 25891,
#  'dear': 22104,
#  'ricardo1': 55685,
#  'red': 54505,
#  'effective': 25513,
#  'direct': 23211,
#  'advertising': 11163,
#  'blue': 15833,
#  'promote': 51922,
#  'business': 16952,
#  'low': 41535,
#  'addresses': 11004,
#  '44c300': 5104,
#  'maximize': 42778,
#  '309': 3925,
#  '407': 4934,
#  '7378': 7196,
#  'consultant': 20252,
#  'discuss': 23353,
#  'needs': 45616,
#  '___________________________________________________________________': 9560,
#  '_______________________________________________________________': 9556,
#  '________________________________________________________________': 9557,
#  'city': 18891,
#  '_____________________________________________________________________': 9561,
#  'phone': 50212,
#  '__________________________________________________________________': 9559,
#  '_______________________________________________________': 9549,
#  '___________________________________________________________________________': 9565,
#  'comments': 19683,
#  'details': 22734,
#  'pricing': 51642,
#  'market': 42586,
#  '247': 3166,
#  'po1': 50881,
#  'kj': 39172,
#  '_8j7bjk9': 9515,
#  'tg0bk5nkiys5': 62648,
#  'cellular': 18190,
#  'accessories': 10683,
#  'wholesale': 68804,
#  'prices': 51638,
#  '202': 2745,
#  '101': 1139,
#  '163': 1837,
#  'merchant': 43233,
#  'hands': 32339,
#  'ear': 25184,
#  'buds': 16783,
#  'holsters': 33454,
#  '98': 9022,
#  'booster': 16144,
#  'antennas': 12576,
#  'cases': 17842,
#  'car': 17720,
#  'chargers': 18451,
#  'plates': 50658,
#  'lithium': 41091,
#  'ion': 36586,
#  'batteries': 14723,
#  '94': 8922,
#  'nokia': 46326,
#  'motorola': 44398,
#  'lg': 40651,
#  'nextel': 45902,
#  'samsung': 57063,
#  'qualcomm': 53322,
#  'ericsson': 26543,
#  'audiovox': 13641,
#  'phones': 50218,
#  'assistance': 13375,
#  '732': 7183,
#  '751': 7246,
#  '1457': 1667,
#  'mailings': 42274,
#  'request': 55149,
#  'removemenow68994': 54961,
#  'thank': 62688,
#  'super': 61107,
#  'free4pornlovers': 29335,
#  'simply': 58713,
#  'amateur': 12190,
#  '990000': 9060,
#  '660066': 6633,
#  '9933ff': 9068,
#  'girl': 30809,
#  'door': 23958,
#  'tour': 63514,
#  'ff0099': 28154,
#  'photos': 50243,
#  'sneeky': 59316,
#  'nude': 46701,
#  'exibitionists': 27125,
#  'cheating': 18514,
#  'wives': 69071,
#  'girlfriends': 30811,
#  'pl': 50596,
#  'cell': 18175,
#  'spacer': 59662,
#  '185': 2033,
#  'rowspan': 56226,
#  'qbfuiexorxkl': 52820,
#  '168': 1872,
#  '143': 1650,
#  '181': 2010,
#  'htmlemails': 33831,
#  't193no_option_01': 61685,
#  't193no_option_02': 61686,
#  't193no_option_03': 61687,
#  't193no_option_04': 61688,
#  't193no_option_05': 61689,
#  't193no_option_06': 61690,
#  '115': 1352,
#  't193no_option_07': 61691,
#  '154': 1755,
#  't193no_option_08': 61692,
#  't193no_option_09': 61693,
#  't193no_option_10': 61694,
#  't193no_option_11': 61695,
#  't193no_option_12': 61696,
#  't193no_option_13': 61697,
#  't193no_option_14': 61698,
#  '265': 3274,
#  'simplywireless': 58714,
#  'swdotcomlogo1': 61359,
#  '273': 3340,
#  'voicestream': 67192,
#  'wireless': 69017,
#  'credit': 20901,
#  'approval': 12884,
#  'activate': 10862,
#  'activation': 10865,
#  'fee': 28034,
#  'applies': 12841,
#  'activations': 10866,
#  'available': 13816,
#  'areas': 13044,
#  'fulfilled': 29674,
#  'authorized': 13723,
#  'dealer': 22095,
#  'site': 58795,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY, 
                                                   test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (3080, 73683)

# %%
X_test.shape
# Out:
# (1320, 73683)

# %%
classifier = MultinomialNB() # our naive bayes model(Training)

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# **Challenge:** Calculate the following for the test dataset: <br>
# The number of documents classified correctly. <br>
# The number of documents classified incorrectly. <br>
# The accuracy of the model. <br>

# %%
nr_correct = (y_test == classifier.predict(X_test)).sum() # how many predictions are correct
classifier.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
print(f'{nr_correct} documents classfied correctly')
# Out:
# 1290 documents classfied correctly

# %%
nr_incorrect = y_test.size - nr_correct # how many predicitions are incorrect

# %%
print(f'Number of documents incorrectly classified is {nr_incorrect}')
# Out:
# Number of documents incorrectly classified is 30

# %%
fraction_wrong = nr_incorrect / (nr_correct + nr_incorrect) # Models testing accuracy
print(f'The (testing) accuracy of the model is {1-fraction_wrong:.2%}')
# Out:
# The (testing) accuracy of the model is 97.73%

# %%
classifier.score(X_test, y_test) # Models score
# Out:
# 0.9772727272727273

# %% [markdown]
# **Challenge:** For the testing dataset calculate the recall, precision and f1 score. Google for the scikit learn documentation on this topic to work it out.

# %%
recall_score(y_test, classifier.predict(X_test)) # Models recall score
# Out:
# 0.8275862068965517

# %%
precision_score(y_test, classifier.predict(X_test)) # Models precision score
# Out:
# 0.96

# %%
f1_score(y_test, classifier.predict(X_test)) # Models F1 score
# Out:
# 0.888888888888889

# %% [markdown]
# ### Another example

# %%
example = ['get viagra for free now!', 
          'need a mortgage? Reply to arrange a call with a specialist and get a quote', 
          'Could you please help me with the project for tomorrow?', 
          'Hello Jonathan, how about a game of golf tomorrow?', 
          'Ski jumping is a winter sport in which competitors aim to achieve the longest jump after descending from a specially designed ramp on their skis. Along with jump length, competitor\'s style and other factors affect the final score. Ski jumping was first contested in Norway in the late 19th century, and later spread through Europe and North America in the early 20th century. Along with cross-country skiing, it constitutes the traditional group of Nordic skiing disciplines.'
          ]

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict(doc_term_matrix) # 2nd email is spam
# Out:
# array([0, 1, 0, 0, 0], dtype=int64)
